# %% [markdown]
# <a href="https://colab.research.google.com/github/Yedoprada245/cd_202202_erwing_prada/blob/main/Taller_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math
import random 
def distancia(x,y):
  return math.sqrt(x**2+y**2)

# %%
cont=0
puntosLado=10000
paso=1/(puntosLado-1)
i=0
while (i<=1):
  j=0
  while (j<=1):
    if distancia(i,j)<=1:
      cont+=1
    j+=paso
  i+=paso

print("puntos:",cont)
print("estimación de pi:",(cont*4/puntosLado**2))

# %%
pAle=1000000

cAle=0
for i in range(pAle):
  x=random.random()
  y=random.random()
  if (distancia(x,y)<=1):

    cAle+=1

print("estimación de pi:",(cAle*4/pAle**2))
